# %%
# Navigate to the src of the repository for standardized imports
# %cd ..

# %%
from template_app.obdeleven_services.databricks import fetch_databricks_data

QUERY_FAULT_DESCRIPTIONS = """
    SELECT _id, en
    FROM texttable.silver_texttable
    LIMIT 10
"""

data = fetch_databricks_data(QUERY_FAULT_DESCRIPTIONS)

data.head() # Example EDA
